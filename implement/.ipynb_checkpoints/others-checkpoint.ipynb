# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bokeh as bk
import sqlalchemy as sqc
from ols_pwp import pwpTasks as opt
from ols_pwp import pwpOLS as opp
from ols_pwp import pwpDeviation as opd

# %%
help(ols_pwp)
# Out:
# Help on module ols_pwp:
#
# NAME
#     ols_pwp - # Loading all the required libraries
#
# CLASSES
#     builtins.object
#         pwpOLS
#             pwpDeviation
#         pwpTasks
#
#     class pwpDeviation(pwpOLS)
#      |  pwpDeviation(dfA, dfB)
#      |
#      |  This class will hold the common variables that will be used as variables in
#      |  create the squared_dev method (method to compute sum of squared deviations)
#      |  and max_dev method (method to compute the max deviation and return a value).
#      |
#      |  Method resolution order:
#      |      pwpDeviation
#      |      pwpOLS
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  max_dev(self)
#      |      This class will compute the max deviations from the two DataFrame inputs.
#      |
#      |      Argument(s): dfA, dfB
#      |
#      |      Return(s): max_deviation
#      |
#      |  ----------------------------------------------------------------------
# ...

# %%
#filepath_train = "C:\Users\tosin\GIT_clones\tosinaa_dlmdspwp01\datasets\train.csv"
train = opt.df_loader(r"C:\Users\tosin\GIT_clones\tosinaa_dlmdspwp01\datasets\train.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12540\350758465.py in <module>
#       1 #filepath_train = "C:\Users\tosin\GIT_clones\tosinaa_dlmdspwp01\datasets\train.csv"
# ----> 2 train = opt.df_loader(r"C:\Users\tosin\GIT_clones\tosinaa_dlmdspwp01\datasets\train.csv")
#
# TypeError: df_loader() missing 1 required positional argument: 'filepath'
